# %%
import numpy as np
import nltk
# import word2vec
import transformers
import requests
import pandas as pd
import matplotlib.pyplot as plt


datasource_config_file = '../data/datasources.yaml'

# %% [markdown]
# # Exemplo Simples com Word2Vec

# %%
# Import necessary libraries
import gensim
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Example sentences (corpus)
corpus = [
    ['gato', 'correu', 'rapidamente', 'atrás', 'do', 'rato'],
    ['o', 'gato', 'é', 'rápido', 'e', 'esperto'],
    ['o', 'rato', 'se', 'escondeu', 'na', 'toca'],
    ['o', 'cachorro', 'latia', 'enquanto', 'corria', 'atrás', 'do', 'gato'],
    ['os', 'gatos', 'e', 'os', 'cachorros', 'não', 'se', 'dão', 'bem'],
    ['o', 'cachorro', 'é', 'amigo', 'do', 'humano'],
    ['o', 'rato', 'tentou', 'escapar', 'do', 'gato']
]

# Train the Word2Vec model
model = Word2Vec(corpus, vector_size=10, window=2, min_count=1, workers=4)

# Get words in the model's vocabulary
words = list(model.wv.index_to_key)

# Get the word embeddings
word_embeddings = [model.wv[word] for word in words]

# Use PCA to reduce the dimensions to 2D for visualization
pca = PCA(n_components=2)
result = pca.fit_transform(word_embeddings)

# Plot the embeddings in 2D
plt.figure(figsize=(6, 6))
plt.scatter(result[:, 0], result[:, 1])

# Annotate each point with the corresponding word
for i, word in enumerate(words):
    plt.annotate(word, xy=(result[i, 0], result[i, 1]))

# Show the plot
plt.title('Word Embeddings Visualized in 2D using PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# %% [markdown]
# # Corpus Machado de Assis

# %%
filepath = '../data/machado/obras_machado_de_assis.csv'

data = pd.read_csv(filepath, index_col=None)
data.head(2)
# Out:
#           arquivo              caminho completo categoria             autor  \
# 0  revelacoes.pdf  ./pdf/crítica/revelacoes.pdf   crítica  Machado de Assis
# 1   magalhaes.pdf   ./pdf/crítica/magalhaes.pdf   crítica  Machado de Assis
#
#    paginas                                             titulo  \
# 0        5  Revelações. Poesias de A. E. Zaluar, Garnier e...
# 1        4  Magalhães de Azeredo: Horas sagradas; Mário de...
#
#                                               edicao  \
# 0  Texto-Fonte: Crítica Literária de Machado de A...
# 1  Texto-Fonte: Obra Completa de Machado de Assis...
#
#                                           publicacao  publicacao ano  \
# 0  Publicado originalmente no Diário do Rio de Ja...            1863
# 1       Publicado na Gazeta de Notícias, 07/12/1902.            1902
#
#          publicacao editora publicacao cidade  edicao ano edicao editora  \
# 0  Diário do Rio de Janeiro    Rio de Janeiro        1938  W. M. Jackson
# 1        Gazeta de Notícias    Rio de Janeiro        1994   Nova Aguilar
#
#     edicao cidade                          edicao titulo edicao volume  \
# 0  Rio de Janeiro  Crítica Literária de Machado de Assis           NaN
# 1  Rio de Janeiro      Obra Completa de Machado de Assis           III
#
#                                                texto
# 0  Revelações. Poesias de A. E. Zaluar, Garnier e...
# 1  Magalhães de Azeredo: Horas sagradas; Mário de...

# %% [markdown]
# ## Quantidade de Obras por Categoria

# %%
(data.groupby('categoria')
    .arquivo.nunique()
    .sort_values()
    .plot.barh(
        xlabel='Total Obras',
        grid=1,
        title='Distribuição de Obras por Categoria'
    )
)
# Out:
# <Axes: title={'center': 'Distribuição de Obras por Categoria'}, xlabel='Total Obras', ylabel='categoria'>

# %% [markdown]
# ## Pré-processamento do Corpus para montar o Vocabulário

# %%
category_name = 'romance'

# SELECAO DE OBRAS DA CATEGORIA
corpus = data[data.categoria == category_name].texto.tolist()
obras = data[data.categoria == category_name].titulo.tolist()
print('Corpus com', len(corpus), 'obras')

# PROCESSO SEPARACAO DE PALAVRAS
# words = nltk.tokenize.word_tokenize(obras[1])
# words = [nltk.tokenize.word_tokenize(o) for o in corpus] # por obra
# words = [nltk.tokenize.wordpunct_tokenize(o) for o in corpus] # por obra
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
corpus = [tokenizer.tokenize(o) for o in corpus] # por obra

# DOWNLOAD DOS ARQUIVOS COM STOPWORDS
nltk.download('stopwords')
from nltk.corpus import stopwords
pt_stopwords = stopwords.words('portuguese')
print('Total de stopwords', len(pt_stopwords))
corpus = [[w for w in o if w not in pt_stopwords] for o in corpus]
corpus[0][:20]
# Out:
# Corpus com 10 obras
# Total de stopwords 207
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rafae\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['Memórias',
#  'Póstumas',
#  'Brás',
#  'Cubas',
#  'Ao',
#  'verme',
#  'primeiro',
#  'roeu',
#  'frias',
#  'carnes',
#  'cadáver',
#  'dedico',
#  'saudosa',
#  'lembrança',
#  'Memórias',
#  'Póstumas',
#  'Prólogo',
#  'terceira',
#  'edição',
#  'A']

# %% [markdown]
# ## Word2Vec

# %%
model = gensim.models.Word2Vec(
    sentences=corpus,
    vector_size=100,
    alpha=0.025,
    window=25,
    min_count=10,
    seed=1,
    workers=3,
    sg=0,
)

# Train the Word2Vec model
# model = Word2Vec(corpus, vector_size=20, window=10, min_count=5, workers=4)
# Get words in the model's vocabulary
words = list(model.wv.index_to_key)
# Get the word embeddings
word_embeddings = [model.wv[word] for word in words]
# Use PCA to reduce the dimensions to 2D for visualization
pca = PCA(n_components=2)
result = pca.fit_transform(word_embeddings)

# %%
def strip_score(result):
    return [w for w, s in result]
# Lista as palavras mais próximas
def closest_words(word, model, num=5):
    word_score_pair = model.wv.most_similar(word, topn=num)
    return strip_score(word_score_pair)

# %%
keyword = 'homem' #, 'Cubas', 'Brás', 'Capitu','Bentinho']


# Plot the embeddings in 2D
plt.figure(figsize=(10, 10))
plt.scatter(result[:, 0], result[:, 1], marker='.')
# Annotate each point with the corresponding word
annotate_words = closest_words(keyword, model, num=10)
for word in annotate_words:    
    xpos = pca.transform([model.wv[word]])
    plt.annotate(word, xy=xpos[0], size=14, c='k')
xpos = pca.transform([model.wv[keyword]])
plt.annotate(keyword, xy=xpos[0], c='red', size=14)
# Show the plot
plt.title('Word Embeddings Visualized in 2D using PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# %% [markdown]
# # Corpus Brasileiro

# %%
import glob

filepaths = glob.glob('../data/Brazilian_Portugese_Corpus/*.txt')
corpus = [' '.join(open(f, encoding='latin-1').readlines()) for f in filepaths]

from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
corpus = [tokenizer.tokenize(o) for o in corpus] # por obra

# DOWNLOAD DOS ARQUIVOS COM STOPWORDS
nltk.download('stopwords')
from nltk.corpus import stopwords
pt_stopwords = stopwords.words('portuguese')
print('Total de stopwords', len(pt_stopwords))
corpus = [[w for w in o if w not in pt_stopwords] for o in corpus]
# UNIDECODE
from unidecode import unidecode
corpus = [unidecode(' '.join(o).lower()) for o in corpus]
corpus = [tokenizer.tokenize(o) for o in corpus] # por obra

len(corpus)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rafae\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Total de stopwords 207
# 81

# %%
# %%time

model = gensim.models.Word2Vec(
    sentences=corpus,
    vector_size=20,
    # alpha=0.025,
    window=10,
    min_count=10,
    seed=1,
    workers=8,
    sg=0,
    epochs = 100
)

# Train the Word2Vec model
# model = Word2Vec(corpus, vector_size=20, window=10, min_count=5, workers=4)
# Get words in the model's vocabulary
words = list(model.wv.index_to_key)
# Get the word embeddings
word_embeddings = [model.wv[word] for word in words]
# Use PCA to reduce the dimensions to 2D for visualization
pca = PCA(n_components=2)
result = pca.fit_transform(word_embeddings)
# Out:
# CPU times: total: 1min 57s
# Wall time: 18.8 s

# %%
len(model.wv.key_to_index)
# Out:
# 19629

# %%
# model.wv.key_to_index
model.wv.index_to_key
# Out:
# ['e',
#  'o',
#  'a',
#  'nao',
#  'ainda',
#  'disse',
#  'casa',
#  'la',
#  'bem',
#  'olhos',
#  'mas',
#  'd',
#  'tudo',
#  'tao',
#  'tempo',
#  'homem',
#  'entao',
#  'que',
#  'porque',
#  'todos',
#  'dia',
#  'senhor',
#  'vez',
#  'sobre',
#  'outro',
#  'amor',
#  'lo',
#  'assim',
#  'mulher',
#  'havia',
#  'dois',
#  'nada',
#  'agora',
#  'pois',
#  'pouco',
#  'onde',
#  'noite',
#  'vida',
#  'sempre',
#  'pai',
#  'outra',
#  'senhora',
#  'porem',
#  'pode',
#  'logo',
#  'ia',
#  'moca',
#  'coracao',
#  'coisa',
#  'toda',
#  'fazer',
#  'grande',
#  'mim',
#  'nunca',
#  'ver',
#  'duas',
#  'todo',
#  'vezes',
#  'mao',
#  'filha',
#  'alguma',
#  'alma',
#  'menos',
#  'era',
#  'dias',
#  'mae',
#  'eu',
#  'dizer',
#  'ter',
#  'podia',
#  'cabeca',
#  'aqui',
#  'anos',
#  'meio',
#  'antes',
#  'sim',
#  'se',
#  'dar',
#  'todas',
#  'voz',
#  'velho',
#  'mal',
#  'si',
#  'porta',
#  'ai',
#  'fez',
#  'deus',
#  'por',
#  'tres',
#  'algum',
#  'rua',
#  'os',
#  'alguns',
#  'marido',
#  'ali',
#  'sei',
#  'horas',
#  'bom',
#  'primeiro',
#  'maos',
#  'outros',
#  'amigo',
#  'palavras',
#  'melhor',
#  'tanto',
#  'lado',
#  'vai',
#  'talvez',
#  'respondeu',
#  'mesma',
#  'perguntou',
#  'parte',
#  'sala',
#  'olhar',
#  'sr',
#  'de',
#  'filho',
#  'as',
#  'ora',
#  'verdade',
#  'apenas',
#  'um',
#  'mundo',
#  'ninguem',
#  'tal',
#  'oh',
#  'quando',
#  'quase',
#  'fim',
#  'espirito',
#  'hoje',
#  'primeira',
#  'pobre',
#  'ah',
#  'desde',
#  'palavra',
#  'ir',
#  'menina',
#  'novo',
#  'moco',
#  'quer',
#  'nome',
#  'momento',
#  'deu',
#  'familia',
#  'rosto',
#  'contra',
#  'ideia',
#  'como',
#  'cada',
#  'ja',
#  'quanto',
#  'tarde',
#  'no',
#  'carta',
#  'parecia',
#  'preciso',
#  'gente',
#  'boa',
#  'maria',
#  'pe',
#  'terra',
#  'caso',
#  'dentro',
#  'sabe',
#  'viu',
#  'razao',
#  'hora',
#  'corpo',
#  'uma',
#  'em',
#  'longe',
#  'capitulo',
#  'falar',
#  'outras',
#  'fazia',
#  'dizia',
#  'rio',
#  'enquanto',
#  'ficou',
#  'jorge',
#  'modo',
#  'quarto',
#  'algumas',
#  'casamento',
#  'esta',
#  'ele',
#  'ceu',
#  'forca',
#  'quero',
#  'lugar',
#  'coisas',
#  'homens',
#  'foi',
#  'queria',
#  'devia',
#  'velha',
#  'nesse',
#  'qualquer',
#  'exclamou',
#  'ao',
#  'bracos',
#  'ar',
#  'certo',
#  'veio',
#  'enfim',
#  'rapaz',
#  'saber',
#  'parece',
#  'cidade',
#  'morte',
#  've',
#  'flor',
#  'bela',
#  'labios',
#  'sabia',
#  'pes',
#  'instante',
#  'triste',
#  'vou',
#  'desse',
#  'para',
#  'durante',
#  'da',
#  'diante',
#  'respeito',
#  'depois',
#  'vinha',
#  'silencio',
#  'ocasiao',
#  'luz',
#  'com',
#  'faz',
#  'felicidade',
#  'chegou',
#  'posso',
#  'desta',
#  'boca',
#  'alem',
#  'mil',
#  'entretanto',
#  'quem',
#  'vontade',
#  'vamos',
#  'maior',
#  'braco',
#  'janela',
#  'senao',
#  'dinheiro',
#  'mesa',
#  'comigo',
#  'ponto',
#  'manha',
#  'ca',
#  'sol',
#  'vi',
#  'feliz',
#  'ela',
#  'padre',
#  'passou',
#  'dava',
#  'amigos',
#  'br',
#  'passar',
#  'joao',
#  'dessa',
#  'pessoa',
#  'deve',
#  'afinal',
#  'ambos',
#  'vem',
#  'deixou',
#  'quatro',
#  'ha',
#  'deste',
#  'voltou',
#  'gesto',
#  'via',
#  'feito',
#  'lagrimas',
#  'caminho',
#  'jantar',
#  'sentia',
#  'uns',
#  'quis',
#  'sair',
#  'nead',
#  'unama',
#  'papel',
#  'www',
#  'cena',
#  'saiu',
#  'rosa',
#  'creio',
#  'daquele',
#  'gosto',
#  'ficar',
#  'seguinte',
#  'daquela',
#  'viuva',
#  'continuou',
#  'tornou',
#  'achava',
#  'causa',
#  'efeito',
#  'sangue',
#  'sao',
#  'entrou',
#  'direito',
#  'nova',
#  'pedro',
#  'proprio',
#  'apesar',
#  'simples',
#  'sorriso',
#  'diabo',
#  'prazer',
#  'tem',
#  'neste',
#  'esperanca',
#  'vista',
#  'muitas',
#  'meia',
#  'na',
#  'volta',
#  'grandes',
#  'duvida',
#  'comecou',
#  'passado',
#  'ouvir',
#  'nenhum',
#  'cinco',
#  'pais',
#  'janeiro',
#  'desejo',
#  'vendo',
#  'medo',
#  'fundo',
#  'embora',
#  'vinte',
#  'lucia',
#  'entrar',
#  'cabelos',
#  'passo',
#  'cor',
#  'natureza',
#  'possivel',
#  'perto',
#  'manuel',
#  'meu',
#  'naquele',
#  'seio',
#  'dai',
#  'chao',
#  'dr',
#  'junto',
#  'mancebo',
#  'sombra',
#  'historia',
#  'esposa',
#  'flores',
#  'luis',
#  'deixar',
#  'nessa',
#  'segredo',
#  'amanha',
#  'irmao',
#  'sociedade',
#  'medico',
#  'rei',
#  'pessoas',
#  'disso',
#  'felix',
#  'trabalho',
#  'poder',
#  'diz',
#  'paixao',
#  'fogo',
#  'dizendo',
#  'reis',
#  'muita',
#  'meses',
#  'es',
#  'isabel',
#  'v',
#  'fazendo',
#  'ouro',
#  'natural',
#  'passava',
#  'alto',
#  'propria',
#  'nenhuma',
#  'ouviu',
#  'passos',
#  'jose',
#  'tinha',
#  'helena',
#  'estado',
#  'naquela',
#  'mar',
#  'paulo',
#  'semelhante',
#  'dez',
#  'conta',
#  'capitao',
#  'peito',
#  'contrario',
#  'deixa',
#  'segundo',
#  'ama',
#  'este',
#  'crianca',
#  'los',
#  '3',
#  'achou',
#  'principio',
#  'cair',
#  'graca',
#  'minutos',
#  'futuro',
#  'capaz',
#  'digo',
#  'senhoras',
#  'muitos',
#  'dor',
#  'viagem',
#  'ultima',
#  'forte',
#  'tomou',
#  'agua',
#  'ano',
#  'tomar',
#  'pena',
#  'irma',
#  'doce',
#  'jardim',
#  'falta',
#  'sentiu',
#  'casar',
#  'consciencia',
#  'peri',
#  'somente',
#  'abriu',
#  'fortuna',
#  'pensamento',
#  'movimento',
#  'sentimento',
#  'estacio',
#  'vao',
#  'canto',
#  'joana',
#  'nem',
#  'resto',
#  'iam',
#  'cama',
#  'belo',
#  'defronte',
#  'acabava',
#  'ultimo',
#  'mulheres',
#  'ti',
#  'morrer',
#  'so',
#  'trazia',
#  'va',
#  'pequena',
#  'idade',
#  'esperava',
#  'rubiao',
#  'chegar',
#  'escrava',
#  'beleza',
#  'cima',
#  'livro',
#  'amancio',
#  'corte',
#  'henrique',
#  'estas',
#  'cheio',
#  'alguem',
#  'amante',
#  'tens',
#  'tendo',
#  'candida',
#  'certa',
#  'alegria',
#  'ordem',
#  'amiga',
#  'viver',
#  'pequeno',
#  'menor',
#  'mau',
#  'frente',
#  'honra',
#  'companhia',
#  'repente',
#  'cuja',
#  'expressao',
#  'pedir',
#  'tu',
#  'filhos',
#  'passeio',
#  'espera',
#  'vir',
#  'vestido',
#  'consigo',
#  'cecilia',
#  'bonita',
#  'demais',
#  'rir',
#  'adriano',
#  'comendador',
#  'minha',
#  'tom',
#  'virgem',
#  'festa',
#  'ouvido',
#  'carro',
#  'especie',
#  'tambem',
#  'honorina',
#  'chapeu',
#  'santa',
#  'naturalmente',
#  'noticia',
#  'aurelia',
#  'impossivel',
#  'conversa',
#  'presenca',
#  'alegre',
#  'ergueu',
#  'cavalo',
#  'costume',
#  'levantou',
#  'diga',
#  'falou',
#  'portanto',
#  'menino',
#  'unico',
#  'cara',
#  'livre',
#  'adeus',
#  'faca',
#  'eis',
#  'tia',
#  'infeliz',
#  'povo',
#  'resposta',
#  'poucos',
#  'fica',
#  'motivo',
#  'correu',
#  'pareceu',
#  'ideias',
#  'sido',
#  'antonio',
#  'teatro',
#  'face',
#  'fato',
#  'amo',
#  'terrivel',
#  'estava',
#  'voltar',
#  'falava',
#  'poderia',
#  'andar',
#  'existencia',
#  'gloria',
#  'olha',
#  'ficava',
#  'campo',
#  'eduardo',
#  'fazenda',
#  'breve',
#  'perder',
#  'prima',
#  'doutor',
#  'mocas',
#  'linda',
#  'amava',
#  'quais',
#  'visto',
#  'posicao',
#  'borges',
#  'qual',
#  'cujo',
#  'ouvi',
#  'dando',
#  'figura',
#  'segunda',
#  'chama',
#  'guarda',
#  'musica',
#  'branca',
#  'fala',
#  'dessas',
#  'unica',
#  'negocio',
#  'cadeira',
#  'desses',
#  'ler',
#  'todavia',
#  'sinal',
#  'depressa',
#  'arnaldo',
#  'baile',
#  'viva',
#  'amizade',
#  'pudesse',
#  'chefe',
#  'ontem',
#  'visita',
#  'daqui',
#  'sob',
#  'levar',
#  'liberdade',
#  'obra',
#  'mor',
#  'sono',
#  'perdao',
#  'vespera',
#  'miguel',
#  'crime',
#  'primeiros',
#  'nele',
#  'necessidade',
#  'pensava',
#  'interesse',
#  'atencao',
#  'leve',
#  'devo',
#  'esperar',
#  'mestre',
#  'tais',
#  'adelaide',
#  'ponta',
#  'politica',
#  'pediu',
#  'pensar',
#  'certeza',
#  'justamente',
#  'nobre',
#  'queres',
#  'mariana',
#  'nesta',
#  'apareceu',
#  'seis',
#  'baixo',
#  'tio',
#  'noites',
#  'rico',
#  'confianca',
#  'major',
#  'cedo',
#  'amar',
#  'coraco',
#  'cartas',
#  'julia',
#  'cheia',
#  'lembrou',
#  'raimundo',
#  'basta',
#  'guerreiro',
#  'publico',
#  'raquel',
#  'geral',
#  'pos',
#  'ouvia',
#  'coronel',
#  'mata',
#  'sorrindo',
#  'lembranca',
#  'destino',
#  'carater',
#  'animo',
#  'grito',
#  'contar',
#  'oito',
#  'correr',
#  'animal',
#  'contos',
#  'servico',
#  'vossa',
#  'alvaro',
#  'esse',
#  'levou',
#  'vice',
#  's',
#  'rapariga',
#  'forma',
#  'sabes',
#  'vale',
#  'ines',
#  'imaginacao',
#  'murmurou',
#  'jovem',
#  'recebeu',
#  'augusto',
#  'acabou',
#  'brasil',
#  'receber',
#  'governo',
#  'acudiu',
#  'clarinha',
#  'escravo',
#  'curiosidade',
#  'ouvidor',
#  'anjo',
#  'azul',
#  'voltando',
#  'posto',
#  'conhecia',
#  'guerra',
#  'chamar',
#  'dedos',
#  'longo',
#  'olhe',
#  'memoria',
#  'olhou',
#  'fronte',
#  'negro',
#  'acrescentou',
#  'imagem',
#  'sorriu',
#  'caiu',
#  'formosa',
#  'desgraca',
#  'instantes',
#  'tristeza',
#  'dormir',
#  'umas',
#  'bastante',
#  'saia',
#  'iaia',
#  'fiz',
#  'favor',
#  'haviam',
#  'objeto',
#  'tanta',
#  'vira',
#  'voce',
#  'nela',
#  'branco',
#  'gabinete',
#  'deixando',
#  'ma',
#  'finalmente',
#  'do',
#  'fe',
#  'dado',
#  'acha',
#  'largo',
#  'igreja',
#  'las',
#  'tempos',
#  'padrinho',
#  'ernesto',
#  'mendonca',
#  'deixava',
#  'exemplo',
#  'desespero',
#  'interior',
#  'gabriel',
#  'seixas',
#  'ferro',
#  'sorte',
#  'doente',
#  'dito',
#  'acaso',
#  'anda',
#  'imediatamente',
#  'direita',
#  'frio',
#  'senhores',
#  'perfeitamente',
#  'dona',
#  'aquela',
#  'estudante',
#  'costas',
#  'dera',
#  'grave',
#  'mes',
#  'estou',
#  'leonardo',
#  'dever',
#  'atras',
#  'questao',
#  'vivo',
#  'realmente',
#  'lingua',
#  'vejo',
#  'torno',
#  'gracas',
#  'ricardo',
#  'roupa',
#  'escrever',
#  'escravos',
#  'ato',
#  'cruel',
#  'paciencia',
#  'achar',
#  'criado',
#  'forcas',
#  'rindo',
#  'distancia',
#  'alexandre',
#  'inimigo',
#  'completamente',
#  'verdadeiro',
#  'emilia',
#  'dentes',
#  'alta',
#  'deixe',
#  'tantas',
#  'abrir',
#  'joelhos',
#  'obrigado',
#  'almoco',
#  'beijo',
#  'querer',
#  'jeronimo',
#  'tenho',
#  'pensou',
#  'candido',
#  'situacao',
#  'ate',
#  'debaixo',
#  'livros',
#  'contas',
#  'conde',
#  'fizera',
#  'angelo',
#  'pescoco',
#  'sentir',
#  'ambrosina',
#  'aspecto',
#  'sentimentos',
#  'frederico',
#  'vergonha',
#  'espaco',
#  'donde',
#  'lembra',
#  'contava',
#  'n',
#  'santo',
#  'noiva',
#  'mostrar',
#  'miranda',
#  'poeta',
#  'ouvindo',
#  'sofia',
#  'sai',
#  'isto',
#  'opiniao',
#  'pior',
#  'fisionomia',
#  'ombros',
#  'ternura',
#  'jogo',
#  'sacrificio',
#  'pernas',
#  'fugir',
#  'ausencia',
#  'cousa',
#  'cabo',
#  'venha',
#  'proposito',
#  'longa',
#  'vulto',
#  'seria',
#  'janelas',
#  'pronto',
#  'sonho',
#  'perigo',
#  'carlos',
#  'colera',
#  'leito',
#  'esperancas',
#  'sinto',
#  'berta',
#  'oficial',
#  'alias',
#  'perdido',
#  'faces',
#  'violante',
#  'companheiros',
#  'vento',
#  'moral',
#  'momentos',
#  'guida',
#  'cuidado',
#  'estela',
#  'escada',
#  'ruas',
#  'riso',
#  'impressao',
#  'pedra',
#  'europa',
#  'encontro',
#  'luta',
#  'semana',
#  'criatura',
#  'bonito',
#  'sua',
#  'isso',
#  'ardente',
#  'fabio',
#  'mandou',
#  'cavalheiro',
#  'profundo',
#  'deveras',
#  'encontrar',
#  'podem',
#  'juro',
#  'andava',
#  'olhando',
#  'companheiro',
#  'dono',
#  'casas',
#  'carlotinha',
#  'sem',
#  'orgulho',
#  'prova',
#  'faziam',
#  'verdadeira',
#  'pergunta',
#  'presente',
#  'parou',
#  'importa',
#  'vinham',
#  'seu',
#  'amelia',
#  'maneira',
#  'rita',
#  'receio',
#  'provincia',
#  'primo',
#  'aquele',
#  'soube',
#  'tomando',
#  'esforco',
#  'amores',
#  'contudo',
#  'vinganca',
#  'tantos',
#  'indio',
#  'chamava',
#  'circunstancias',
#  'podiam',
#  'vivia',
#  'morto',
#  'bras',
#  'peco',
#  'mamae',
#  'praia',
#  'ana',
#  'velhos',
#  'continuava',
#  'profunda',
#  'chorar',
#  'folhas',
#  'servir',
#  'noivo',
#  'braz',
#  'deixara',
#  'ficara',
#  'sujeito',
#  'visitas',
#  'virtude',
#  'leva',
#  'campos',
#  'acho',
#  'margarida',
#  'mostrou',
#  'conhece',
#  'serio',
#  'vitima',
#  'par',
#  'carmo',
#  'tirou',
#  'juntos',
#  'passa',
#  'piedade',
#  'igual',
#  'baixa',
#  'esquerda',
#  'chacara',
#  'principalmente',
#  'leitor',
#  'tirar',
#  'essa',
#  'desejava',
#  'educacao',
#  'corina',
#  'resolucao',
#  'ursula',
#  'surpresa',
#  'asas',
#  'piano',
#  'acabar',
#  ...]

# %%
model.wv['amigo']
# Out:
# array([-0.46138558,  4.9515634 , -1.4684327 , -1.3282678 , -3.9116683 ,
#         1.2381027 ,  2.0295    ,  1.7268482 , -2.4776773 , -3.6701021 ,
#        -3.0983343 ,  4.9996867 , -2.9312894 ,  1.827528  , -0.8823341 ,
#        -0.6832281 ,  1.9593561 ,  3.6482959 , -1.2969728 ,  2.0648706 ],
#       dtype=float32)

# %%
model.wv.most_similar(positive=['vinho'], topn=10)
# Out:
# [('beber', 0.7971099019050598),
#  ('aguardente', 0.7845853567123413),
#  ('gole', 0.7648082375526428),
#  ('acucar', 0.7590029835700989),
#  ('champanha', 0.7556855082511902),
#  ('farinha', 0.7495537996292114),
#  ('bebeu', 0.7419930696487427),
#  ('queijo', 0.736393928527832),
#  ('paradas', 0.7326105237007141),
#  ('garrafa', 0.7274110913276672)]

# %%
model.wv.most_similar(positive=['amigo'], topn=10)
# Out:
# [('seabra', 0.7590705752372742),
#  ('tio', 0.7522890567779541),
#  ('irmao', 0.731381356716156),
#  ('deputado', 0.7185834646224976),
#  ('alves', 0.7066142559051514),
#  ('anselmo', 0.7014023661613464),
#  ('esperas', 0.6893674731254578),
#  ('doutor', 0.6883413791656494),
#  ('major', 0.6873431205749512),
#  ('acertado', 0.680484414100647)]

# %%
model.wv.most_similar(positive=['noivo', 'mulher'], negative = ['homem'] ,topn=10)
# Out:
# [('irma', 0.853527307510376),
#  ('noiva', 0.8525561690330505),
#  ('filha', 0.7754052877426147),
#  ('sobrinha', 0.7673101425170898),
#  ('orfa', 0.7594180703163147),
#  ('fatigada', 0.7264537215232849),
#  ('enxaqueca', 0.7231543660163879),
#  ('extremosamente', 0.7111323475837708),
#  ('viuvez', 0.7076266407966614),
#  ('casada', 0.701438844203949)]

# %%
model.wv.most_similar(positive=['brasil'] ,topn=10)
# Out:
# [('norte', 0.8408389091491699),
#  ('lisboa', 0.8245145678520203),
#  ('capital', 0.820716381072998),
#  ('colonia', 0.8027284741401672),
#  ('reino', 0.7919512987136841),
#  ('minas', 0.7892490029335022),
#  ('nomeacao', 0.7823482155799866),
#  ('brasileiros', 0.7807355523109436),
#  ('brasileiro', 0.7723233699798584),
#  ('holanda', 0.7673590183258057)]

# %%
model.wv.similarity('capitu','bentinho')
# Out:
# 0.5924995

# %%
model.wv.most_similar(positive=['pai', 'mae'], negative=['filho'], topn=10)
# Out:
# [('joaozinho', 0.7764110565185547),
#  ('irma', 0.7309920191764832),
#  ('tia', 0.7048942446708679),
#  ('celina', 0.6926133036613464),
#  ('mano', 0.6908190846443176),
#  ('chorando', 0.6901842951774597),
#  ('querida', 0.6860426068305969),
#  ('filha', 0.6806867718696594),
#  ('perdoou', 0.6789284348487854),
#  ('sobrinha', 0.678907573223114)]

# %% [markdown]
# # Plot dos Embeddings e Determinardos Termos

# %%
annotate_words = ['pai', 'mae','filho', 'filha'] #, 'Cubas', 'Brás', 'Capitu','Bentinho']

# Plot the embeddings in 2D
plt.figure(figsize=(10, 10))
plt.scatter(result[:, 0], result[:, 1], marker='.', alpha=0.2)
# Annotate each point with the corresponding word
for word in annotate_words:    
    xpos = pca.transform([model.wv[word]])
    plt.annotate(word, xy=xpos[0], size=16, c='#993322', weight='bold')
    plt.plot(xpos[0][0], xpos[0][1], 'x', c='#993322')
# Show the plot
plt.title('Word Embeddings Visualized in 2D using PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# %% [markdown]
# # Plot da Keyword e Termos Similares

# %%
keyword = 'bentinho' #, 'Cubas', 'Brás', 'Capitu','Bentinho']

# Plot the embeddings in 2D
plt.figure(figsize=(10, 10))
plt.scatter(result[:, 0], result[:, 1], marker='.', alpha=0.2)
# Annotate each point with the corresponding word
annotate_words = closest_words(keyword, model, num=5)
for word in annotate_words:    
    xpos = pca.transform([model.wv[word]])
    plt.annotate(word, xy=xpos[0], size=16, c='k', weight='bold')
    plt.plot(xpos[0][0], xpos[0][1], 'kx')
xpos = pca.transform([model.wv[keyword]])
plt.annotate(keyword, xy=xpos[0], size=16, c='#993322', weight='bold')
plt.plot(xpos[0][0], xpos[0][1], 'rx')
# Show the plot
plt.title('Word Embeddings Visualized in 2D using PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# %%
import gensim.downloader as api
model = api.load("glove-wiki-gigaword-50")

# %% [markdown]
# # Embeddings

# %%
import glob
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

model_name = 'neuralmind/bert-base-portuguese-cased'
llm_model_dir = '../data/bertimbau/'


embedding_model = SentenceTransformer(model_name, cache_folder=llm_model_dir, device='cpu')
# Out:
# No sentence-transformers model found with name neuralmind/bert-base-portuguese-cased. Creating a new one with mean pooling.

# %%
filepaths = glob.glob('../data/Brazilian_Portugese_Corpus/*.txt')
corpus = [' '.join(open(f, encoding='latin-1').readlines()) for f in filepaths]
names =  [f.replace('../data/Brazilian_Portugese_Corpus/','').replace('.txt','') for f in filepaths]
names =  [f.replace('../data/Brazilian_Portugese_Corpus\\','').replace('.txt','') for f in filepaths] # windows
meta = pd.read_csv('../data/guideToDocuments.csv')
authors = [meta[meta.Work.str.replace(",", '').str.replace("'",'') == f"{x}.txt"].Author.tolist()[0] for x in names]

# %%
# %%time

embeddings = embedding_model.encode(corpus, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# CPU times: total: 6min 3s
# Wall time: 28 s

# %%
len(embeddings[0])
# Out:
# 768

# %%
from umap import UMAP

umap_model = UMAP(
    n_neighbors=5, 
    n_components=2, 
    min_dist=0.0,
    metric='cosine',
    low_memory=True,
    random_state=42
)
Xumap = umap_model.fit_transform(embeddings)

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import matplotlib.patches

levels, categories = pd.factorize(authors)
colors = [plt.cm.tab20(i) for i in levels] # using the "tab20" colormap
handles = [matplotlib.patches.Patch(color=plt.cm.tab20(i), label=c) for i, c in enumerate(categories)]
plt.scatter(Xumap[:,0], Xumap[:,1], c=pd.factorize(authors)[0], cmap='tab20')
plt.gca().set(xlabel='D1', ylabel='D2', title='Embeddings das Obras Literárias')

# Shrink current axis by 20%
box = plt.gca().get_position()
plt.gca().set_position([box.x0, box.y0, box.width * 0.8, box.height])

# Put a legend to the right of the current axis
plt.gca().legend(handles=handles,  title='Autores', loc='center left', bbox_to_anchor=(1, 0.767))
plt.grid(1)

# %% [markdown]
# ## Exemplos de Embeddings

# %%
example_corpus = [
    'o rei do futebol é o pelé, que nunca jogou para o roma, da italia',
    'o ultimo rei de roma foi tarquinio, o tirano, antes da unificacao da italia',
    'a italia moderna foi unificada com lideranca do rei Victor Manuel',
]
example_label=['Rei Pele', 'Rei Tarquinio', 'Rei Victor']
embeddings = embedding_model.encode(example_corpus, show_progress_bar=True)

pca_model = PCA(n_components=2).fit(embeddings)
Xpca = pca_model.transform(embeddings)
# plt.scatter(Xpca[:,0], Xpca[:,1])
for i, lab in enumerate(example_label):
    plt.plot(Xpca[i,0], Xpca[i,1], 'o', label=example_label[i])



# frase similar de teste
test_example = ['o rei mais tirano que roma ja teve']
embeddings = embedding_model.encode(test_example , show_progress_bar=True)
Xpca = pca_model.transform(embeddings)
plt.scatter(Xpca[:,0], Xpca[:,1], marker='x', label='Test')

plt.legend(loc='best')
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Embeddings Manuais

# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import euclidean

# Dicionário de embeddings para personagens da Marvel
marvel_embeddings = {
    'Homem de Ferro': [0.9, 0.1, 0.7, 0.6, 0.9],
    'Thor':           [0.1, 0.9, 1.0, 1.0, 0.5],
    'Capitã Marvel':  [0.9, 0.7, 1.0, 0.9, 0.7],
    'Hulk':           [0.7, 0.2, 0.0, 1.0, 0.3],
    'Viúva Negra':    [1.0, 0.0, 0.0, 0.5, 0.7],
    'Doutor Estranho':[0.6, 0.7, 0.4, 0.5, 0.9],
    'Groot':          [0.1, 0.0, 0.0, 0.7, 0.4],
    'Odin':           [0.0, 1.0, 0.8, 1.0, 0.8]
}

# Dicionário de embeddings para personagens da DC Comics
dc_embeddings = {
    'Superman':         [0.1, 0.9, 1.0, 1.0, 0.7], # Voar, Força Bruta
    'Batman':           [1.0, 0.0, 0.0, 0.7, 1.0], # Intelecto elevado, Força moderada
    'Mulher-Maravilha': [0.3, 0.7, 0.6, 0.9, 0.7], # Semideusa, Voar
    'Flash':            [1.0, 0.0, 0.0, 0.6, 0.6], # Humano, Velocidade extrema, Inteligência
    'Aquaman':          [0.5, 0.7, 0.2, 0.7, 0.6], # Meio-humano, Meio-atlante
    'Lanterna Verde':   [0.9, 0.6, 0.8, 0.7, 0.8]  # Tecnologia avançada
}

# Definir os nomes das colunas para o DataFrame
columns = ['Humano', 'Deidade', 'Voar', 'Força Bruta', 'Intelecto']
# Criar DataFrame para os personagens da Marvel
df_marvel = pd.DataFrame.from_dict(marvel_embeddings, orient='index', columns=columns)
# Criar DataFrame para os personagens da DC Comics
df_dc = pd.DataFrame.from_dict(dc_embeddings, orient='index', columns=columns)

# Função para calcular a distância euclidiana
def calcular_distancia(personagem_ref, dicionario_personagens):
    distancias = {}
    for personagem, embedding in dicionario_personagens.items():
        dist = euclidean(personagem_ref, embedding)
        distancias[personagem] = dist
    return sorted(distancias.items(), key=lambda x: x[1])

# Comparar personagens da Marvel com outros personagens da Marvel e da DC
def comparar_personagem(personagem, marvel_embeddings, dc_embeddings):
    # Calcular a distância para outros personagens da Marvel
    referencia = marvel_embeddings[personagem]
    print(f"\n--- Comparando com {personagem} ---\n")

    print("Personagens mais próximos (Marvel):")
    distancias_marvel = calcular_distancia(referencia, marvel_embeddings)
    for i, (personagem, dist) in enumerate(distancias_marvel[1:4]):  # Ignora o próprio personagem
        print(f"{i+1}. {personagem} - Distância: {dist:.3f}")

    print("\nPersonagens mais próximos (DC):")
    distancias_dc = calcular_distancia(referencia, dc_embeddings)
    for i, (personagem, dist) in enumerate(distancias_dc[:3]):
        print(f"{i+1}. {personagem} - Distância: {dist:.3f}")

# Comparar os personagens Homem de Ferro, Thor e Hulk com Marvel e DC
# comparar_personagem('Homem de Ferro', marvel_embeddings, dc_embeddings)
# comparar_personagem('Thor', marvel_embeddings, dc_embeddings)
comparar_personagem('Hulk', marvel_embeddings, dc_embeddings)
# Out:
# --- Comparando com Hulk ---
#
# Personagens mais próximos (Marvel):
# 1. Groot - Distância: 0.707
# 2. Viúva Negra - Distância: 0.735
# 3. Doutor Estranho - Distância: 1.015
#
# Personagens mais próximos (DC):
# 1. Flash - Distância: 0.616
# 2. Aquaman - Distância: 0.714
# 3. Batman - Distância: 0.843

# %%
df_marvel
# Out:
#                  Humano  Deidade  Voar  Força Bruta  Intelecto
# Homem de Ferro      0.9      0.1   0.7          0.6        0.9
# Thor                0.1      0.9   1.0          1.0        0.5
# Capitã Marvel       0.9      0.7   1.0          0.9        0.7
# Hulk                0.7      0.2   0.0          1.0        0.3
# Viúva Negra         1.0      0.0   0.0          0.5        0.7
# Doutor Estranho     0.6      0.7   0.4          0.5        0.9
# Groot               0.1      0.0   0.0          0.7        0.4
# Odin                0.0      1.0   0.8          1.0        0.8

# %%
df_dc
# Out:
#                   Humano  Deidade  Voar  Força Bruta  Intelecto
# Superman             0.1      0.9   1.0          1.0        0.7
# Batman               1.0      0.0   0.0          0.7        1.0
# Mulher-Maravilha     0.3      0.7   0.6          0.9        0.7
# Flash                1.0      0.0   0.0          0.6        0.6
# Aquaman              0.5      0.7   0.2          0.7        0.6
# Lanterna Verde       0.9      0.6   0.8          0.7        0.8
